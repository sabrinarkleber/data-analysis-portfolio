# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load data
df = pd.read_csv("patients.csv")

# Step 3: Inspect data (optional)
df.head()
# Out:
#    patient_id program  weight_loss  coach_id
# 0           1       A           12       101
# 1           2       B            5       102
# 2           3       A           10       101
# 3           4       C            7       103
# 4           5       B            8       102

# %%
import matplotlib.pyplot as plt

# Example chart
plt.bar(df['KPI_Name'], df['KPI_Value'])

# Save the chart as an image
plt.savefig("kpi_chart.png", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Grab the current figure (the chart already displayed)
fig = plt.gcf()  # get current figure

# Save it exactly as it is
fig.savefig(r"C:\Users\sabri\data-analysis-portfolio\healthcare-kpi-analysis\healthcare_kpi_chart.png", bbox_inches='tight')
