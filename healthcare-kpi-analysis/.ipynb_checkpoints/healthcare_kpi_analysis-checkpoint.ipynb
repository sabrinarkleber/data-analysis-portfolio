# %%
import pandas as pd

# Load the CSV
df = pd.read_csv('patients.csv')
df
# Out:
#    patient_id program  weight_loss  coach_id
# 0           1       A           12       101
# 1           2       B            5       102
# 2           3       A           10       101
# 3           4       C            7       103
# 4           5       B            8       102
# 5           6       C           15       103
